# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# load dataset
athletes= pd.read_csv('D:/DA/PROJECTS/athlete_events.csv')
regions= pd.read_csv('D:/DA/PROJECTS/noc_regions.csv')

# %%
# Join the Dataframes
df=athletes.merge(regions, how='left', on='NOC')

# %%
# Rename Column Name
df.rename(columns={'region':'Region','notes':'Notes'},inplace=True);

# %%
df.shape
# Out:
# (271116, 17)

# %%
df.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# Region     object
# Notes      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %%
# Fetch Top 5 records
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
# Fetch last 5 records
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal  Region Notes
# ...

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# check null values
df.isnull().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
# count null values in columns
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
# India details
df.query('Team=="India"')

# %%
# Top 10 participating countries
top_10_countries=df.Team.value_counts().sort_values(ascending=False).head(10)
print (top_10_countries)
# Out:
# Team
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: count, dtype: int64

# %%
# plot for top 10 countries
plt.figure(figsize=(12,6))
plt.title('Top 10 participating countries')
sns.barplot(x=top_10_countries.index,y=top_10_countries,palette='Set2');

# %%
# Age distribution of the Participants
plt.figure(figsize=(12,6))
plt.xlabel('Age')
plt.ylabel('Number of Participants')
plt.title('Age distribution of the Athletes')
plt.hist(x=df.Age, bins=np.arange(10,80,2),color='orange',edgecolor='white');

# %%
# unique sporting events in winter olympic
df[df.Season=='Winter'].Sport.unique()
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
# unique sporting events in Summer olympic
df[df.Season=='Summer'].Sport.unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
# male and female participants
gender_counts= df.Sex.value_counts()
print (gender_counts)
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64

# %%
# pie plot distribution for male and female athletes
plt.figure(figsize=(12,6))
plt.xlabel('Age')
plt.ylabel('Number of Participants')
plt.title('distribution for male and female athletes')
plt.pie(gender_counts, labels=gender_counts.index,shadow=True,autopct='%1.2f%%',startangle=180);

# %%
#Total Medals
Medal_counts=df.Medal.value_counts()
print (Medal_counts)
# Out:
# Medal
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: count, dtype: int64

# %%
# Pie plot for Medal Distribution
plt.title('Medal Distribution')
x= Medal_counts
y=Medal_counts.index
plt.pie(x,labels=y,colors=['gold','brown','silver'],shadow=True,autopct='%1.2f%%',startangle=180);

# %%
# total number of female athlete in each olympic
female_participants=df[(df.Sex=='F') & (df.Season=='Summer')][['Sex','Year']].groupby('Year').count().reset_index()
print(female_participants)
# Out:
#     Year   Sex
# 0   1900    33
# 1   1904    16
# 2   1906    11
# 3   1908    47
# 4   1912    87
# 5   1920   134
# 6   1924   244
# 7   1928   404
# 8   1932   347
# 9   1936   468
# 10  1948   628
# 11  1952  1497
# 12  1956   893
# 13  1960  1435
# 14  1964  1348
# 15  1968  1777
# 16  1972  2193
# 17  1976  2172
# 18  1980  1756
# 19  1984  2447
# 20  1988  3543
# 21  1992  4124
# 22  1996  5008
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
female_athletes=df[(df.Sex=='F') & (df.Season=='Summer')]

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=female_athletes,x='Year',palette='Spectral')
plt.title('Female Participants')
# Out:
# Text(0.5, 1.0, 'Female Participants')

# %%
part=female_athletes.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20,10))
part.loc[:,'F'].plot()
plt.title('Line plot of Female Participants')
# Out:
# Text(0.5, 1.0, 'Line plot of Female Participants')

# %%
# Weight vs Height Scatter plot of Male & Female
sns.scatterplot(data=df,x='Weight',y='Height',hue='Sex',palette='Set2')
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
# Athletes who won gold medal 
df[df.Medal=='Gold']
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
# Top 10 countries with gold medal 
df[df.Medal=='Gold'].Team.value_counts().reset_index(name='No. of Gold Medals').head(10)
# Out:
#             Team  No. of Gold Medals
# 0  United States                2474
# 1   Soviet Union                1058
# 2        Germany                 679
# 3          Italy                 535
# 4  Great Britain                 519
# 5         France                 455
# 6         Sweden                 451
# 7        Hungary                 432
# 8         Canada                 422
# 9   East Germany                 369

# %%
# Countries with Maximum no. of Medals
medal_rank=df.groupby('Team')['Medal'].count().sort_values(ascending=False).reset_index(name='count').head(10)
print(medal_rank)
# Out:
#             Team  count
# 0  United States   5219
# 1   Soviet Union   2451
# 2        Germany   1984
# 3  Great Britain   1673
# 4         France   1550
# 5          Italy   1527
# 6         Sweden   1434
# 7      Australia   1306
# 8         Canada   1243
# 9        Hungary   1127

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=medal_rank,x='Team',y='count',palette='rocket')
plt.xlabel('Top 10 Countries')
plt.ylabel('Number of Medals')
plt.title('Female Participants')
plt.show()

# %%
max_year=df.Year.max()
print(max_year)
# Out:
# 2016

# %%
# countries won Gold in Last Olympic
df[(df.Year==2016) & (df.Medal=='Gold')].Team.value_counts().head(10)
# Out:
# Team
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: count, dtype: int64

# %%
df.query('Team=="United States"').head(10)
# Out:
#     ID             Name Sex   Age  Height  Weight           Team  NOC  \
# 10   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 11   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 12   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 13   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 14   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 15   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 16   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 17   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 18   7     John Aalberg   M  31.0   183.0    72.0  United States  USA
# 19   7     John Aalberg   M  31.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 10  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# ...
